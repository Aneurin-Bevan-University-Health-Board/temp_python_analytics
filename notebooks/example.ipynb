# %% [markdown]
# # Example Notebook
# Replace this with your analysis.

# %%
from google.cloud import bigquery
import pandas as pd

client = bigquery.Client(project="your-gcp-project")

sql = """
    SELECT 'hello from BigQuery' AS message
"""

df = client.query(sql).to_dataframe()
print(df)
